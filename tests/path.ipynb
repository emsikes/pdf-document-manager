# %%
import sys
sys.path
# Out:
# ['C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3\\python312.zip',
#  'C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3\\DLLs',
#  'C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3\\Lib',
#  'C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3',
#  'c:\\Users\\cloud\\Documents\\projects\\document-manager\\venv',
#  '',
#  'c:\\Users\\cloud\\Documents\\projects\\document-manager\\venv\\Lib\\site-packages']

# %%
sys.path.append('c:\\Users\\cloud\\Documents\\projects\\document-manager')

# %%
sys.path
# Out:
# ['C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3\\python312.zip',
#  'C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3\\DLLs',
#  'C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3\\Lib',
#  'C:\\Users\\cloud\\.pyenv\\pyenv-win\\versions\\3.12.3',
#  'c:\\Users\\cloud\\Documents\\projects\\document-manager\\venv',
#  '',
#  'c:\\Users\\cloud\\Documents\\projects\\document-manager\\venv\\Lib\\site-packages',
#  'c:\\Users\\cloud\\Documents\\projects\\document-manager']
